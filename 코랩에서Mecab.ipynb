# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 방법1
# [참고](https://github.com/SOMJANG/Mecab-ko-for-Google-Colab)

# %%
! git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git

# %%
cd Mecab-ko-for-Google-Colab
# Out:
# /content/Mecab-ko-for-Google-Colab

# %%
! bash install_mecab-ko_on_colab190912.sh

# %%
from konlpy.tag import Mecab

# %%
mecab = Mecab()

# %%
mecab.morphs('Parrot은 서강대학교 데이터사이언스 학회다.')
# Out:
# ['Parrot', '은', '서강대', '학교', '데이터', '사이언스', '학회', '다', '.']

# %% [markdown]
# # 방법2
# [참고](https://beausty23.tistory.com/61?category=348545)

# %%
# !tar zxfv /content/drive/Shareddrives/Parrot/Jinho/mecab-0.996-ko-0.9.2.tar.gz

# %%
cd /content/mecab-0.996-ko-0.9.2

# %%
# !./configure
# !make
# !make check
# !sudo make install

# %%
cd /content/

# %%
# !tar zxfv /content/drive/Shareddrives/Parrot/Jinho/mecab-ko-dic-2.1.1-20180720.tar.gz

# %%
cd /content/mecab-ko-dic-2.1.1-20180720

# %%
# !./configure
# !make
# !sudo make install

# %%
cd /content/mecab-ko-dic-2.1.1-20180720

# %%
# !mecab -d .

# %%
# !pip install mecab-python3
# !apt-get update
# !apt-get install g++ openjdk-8-jdk python-dev python3-dev
# !pip3 install JPype1-py3
# !pip3 install konlpy
# !JAVA_HOME="/usr/lib/jvm/java-8-openjdk-amd64"

# %%
from konlpy.tag import Mecab
tokenizer = Mecab()

# %%
tokenizer.morphs('Parrot은 서강대학교 데이터사이언스 학회다.')

# %% [markdown]
# # Mecab 이용해 BERT 한국어 vocab.txt

# %% [markdown]
# [데이터다운로드](https://ratsgo.github.io/embedding/downloaddata.html)

# %%
def whitespace_tokenize(data):
  data = data.strip()    # 문자열의 맨앞, 맨끝 공백 지움
  if not data:
    return []
  tokens = data.split()  # 문자열을 스페이스,탭,엔터 단위로 분리하여 배열에 집어넣음
  return tokens

# %%
txt_file = open("/content/drive/Shareddrives/Parrot/Jinho/processed_korquad.txt", 'r')
korquad_data = txt_file.read()
txt_file.close()

# %%
from konlpy.tag import Mecab
tokenizer = Mecab()
    
output_tokens = [ '[PAD]', '[UNK]', '[CLS]', '[SEP]', '[MASK]' ]
for wst in whitespace_tokenize(korquad_data): # wst : 공백,탭,엔터 기준 문자열 하나
    count = 0
    for token in tokenizer.morphs(wst):       # token : wst를 형태소 분석한 토큰 하나
        tk = token

        if count > 0:
            tk = "##" + tk
            if tk in output_tokens:   # 토큰이 중복되면 저장하지 않음
                continue
            output_tokens.append(tk)
        else:  # count==0
            count += 1
            if tk in output_tokens:   # 토큰이 중복되면 저장하지 않음
                continue
            output_tokens.append(tk)  # 맨 처음 token만 앞에 ##을 붙이지 않음

# %%
txt_file = open("/content/drive/Shareddrives/Parrot/Jinho/mecab-vocab.txt", 'w')  # 텍스트 파일을 쓰기 모드로 생성

for token in output_tokens:
  txt_file.write(token + '\n')

txt_file.close()
